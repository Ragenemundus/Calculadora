# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragenemundus/Calculadora/blob/master/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **** SEGUNDO SEMESTRE DE 2023 Agosto AMOXARIFADO

# %%
import pandas as pd

# Dados para a tabela
dados = {
    'produto': ['Abaixador de Língua', 'Água Destilada', 'Agulha 13 x 45', 'Agulha 20 x 5,5', 'Agulha 25 x 07', 'Agulha 25 x 8,0', 'Agulha 30 x 7', 'Agulha 30 x 8', 'Agulha 40 x 12', 'Álcool 70', 'Álcool Absoluto', 'Álcool Gel', 'Algodão Ortopédico', 'Almofada pra Carimbo Preta', 'Glicosímetro', 'Atadura de 10 cm', 'Atadura de 15 cm', 'Atadura de 20 cm', 'Atestado Médico', 'Autoclave', 'Avental Manga Longa', 'Avental Manga Curta', 'Bacia Plástica', 'Bexiga','Balde de 20 alça metal','Balde de 10'],
    'quantidade': [16, 57, 116, 127, 138, 94, 151, 111, 24, 80, 357, 224, 4, 2, 153, 2, 106, 18, 154, 1, 137, 11, 11, 5,18,2],
    'grandeza': ['pacote com 100', 'GL', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'litros', 'litros', '500 ml', 'pct', 'unidades', 'uni', 'pacotes', 'pacotes', 'pacotes', 'blocos', 'unidade', 'pacotes', 'pacotes', 'unidade', 'pacotes','unidades','unidades']
}

# Criar DataFrame
df = pd.DataFrame(dados)

# Exportar para Excel
nome_arquivo = 'tabela_produtos.xlsx'
df.to_excel(nome_arquivo, index=False)
print(f"Tabela exportada para '{nome_arquivo}'")
df
# Out:
# Tabela exportada para 'tabela_produtos.xlsx'
#                        produto  quantidade        grandeza
# 0          Abaixador de Língua          16  pacote com 100
# 1               Água Destilada          57              GL
# 2               Agulha 13 x 45         116              cx
# 3              Agulha 20 x 5,5         127              cx
# 4               Agulha 25 x 07         138              cx
# 5              Agulha 25 x 8,0          94              cx
# 6                Agulha 30 x 7         151              cx
# 7                Agulha 30 x 8         111              cx
# 8               Agulha 40 x 12          24              cx
# 9                    Álcool 70          80          litros
# 10             Álcool Absoluto         357          litros
# 11                  Álcool Gel         224          500 ml
# 12          Algodão Ortopédico           4             pct
# 13  Almofada pra Carimbo Preta           2        unidades
# ...

# %%
import pandas as pd

# Dados existentes no DataFrame
dados = {
    'produto': ['Abaixador de Língua', 'Água Destilada', 'Agulha 13 x 45', 'Agulha 20 x 5,5', 'Agulha 25 x 07', 'Agulha 25 x 8,0', 'Agulha 30 x 7', 'Agulha 30 x 8', 'Agulha 40 x 12', 'Álcool 70', 'Álcool Absoluto', 'Álcool Gel', 'Algodão Ortopédico', 'Almofada pra Carimbo Preta', 'Glicosímetro', 'Atadura de 10 cm', 'Atadura de 15 cm', 'Atadura de 20 cm', 'Atestado Médico', 'Autoclave', 'Avental Manga Longa', 'Avental Manga Curta', 'Bacia Plástica', 'Bexiga', 'Balde de 20 alça metal', 'Balde de 10'],
    'quantidade': [16, 57, 116, 127, 138, 94, 151, 111, 24, 80, 357, 224, 4, 2, 153, 2, 106, 18, 154, 1, 137, 11, 11, 5, 18, 2],
    'grandeza': ['pacote com 100', 'GL', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'litros', 'litros', '500 ml', 'pct', 'unidades', 'uni', 'pacotes', 'pacotes', 'pacotes', 'blocos', 'unidade', 'pacotes', 'pacotes', 'unidade', 'pacotes', 'unidades', 'unidades']
}

# Criar DataFrame
df = pd.DataFrame(dados)

# Adicionar nova entrada
nova_entrada = {'produto': 'Bandeja', 'quantidade': 1, 'grandeza': 'unidade'}
df = df.append(nova_entrada, ignore_index=True)

# Exportar para Excel
nome_arquivo = 'tabela_produtos.xlsx'
df.to_excel(nome_arquivo, index=False)
print(f"Tabela exportada para '{nome_arquivo}'")
print(df)
# Out:
# Tabela exportada para 'tabela_produtos.xlsx'
#                        produto  quantidade        grandeza
# 0          Abaixador de Língua          16  pacote com 100
# 1               Água Destilada          57              GL
# 2               Agulha 13 x 45         116              cx
# 3              Agulha 20 x 5,5         127              cx
# 4               Agulha 25 x 07         138              cx
# 5              Agulha 25 x 8,0          94              cx
# 6                Agulha 30 x 7         151              cx
# 7                Agulha 30 x 8         111              cx
# 8               Agulha 40 x 12          24              cx
# 9                    Álcool 70          80          litros
# 10             Álcool Absoluto         357          litros
# 11                  Álcool Gel         224          500 ml
# 12          Algodão Ortopédico           4             pct
# 13  Almofada pra Carimbo Preta           2        unidades
# ...

# %%
import pandas as pd

# Dados existentes no DataFrame
dados = {
    'produto': ['Abaixador de Língua', 'Água Destilada', 'Agulha 13 x 45', 'Agulha 20 x 5,5', 'Agulha 25 x 07', 'Agulha 25 x 8,0', 'Agulha 30 x 7', 'Agulha 30 x 8', 'Agulha 40 x 12', 'Álcool 70', 'Álcool Absoluto', 'Álcool Gel', 'Algodão Ortopédico', 'Almofada pra Carimbo Preta', 'Glicosímetro', 'Atadura de 10 cm', 'Atadura de 15 cm', 'Atadura de 20 cm', 'Atestado Médico', 'Autoclave', 'Avental Manga Longa', 'Avental Manga Curta', 'Bacia Plástica', 'Bexiga', 'Balde de 20 alça metal', 'Balde de 10'],
    'quantidade': [16, 57, 116, 127, 138, 94, 151, 111, 24, 80, 357, 224, 4, 2, 153, 2, 106, 18, 154, 1, 137, 11, 11, 5, 18, 2],
    'grandeza': ['pacote com 100', 'GL', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'litros', 'litros', '500 ml', 'pct', 'unidades', 'uni', 'pacotes', 'pacotes', 'pacotes', 'blocos', 'unidade', 'pacotes', 'pacotes', 'unidade', 'pacotes', 'unidades', 'unidades']
}

# Criar DataFrame
df = pd.DataFrame(dados)

# Adicionar nova entrada
nova_entrada = {'produto': 'Bolsa coletora de urina', 'quantidade': 41, 'grandeza': 'unidades'}
df = df.append(nova_entrada, ignore_index=True)

# Exportar para Excel
nome_arquivo = 'tabela_produtos.xlsx'
df.to_excel(nome_arquivo, index=False)
print(f"Tabela exportada para '{nome_arquivo}'")
print(df)
# Out:
# Tabela exportada para 'tabela_produtos.xlsx'
#                        produto  quantidade        grandeza
# 0          Abaixador de Língua          16  pacote com 100
# 1               Água Destilada          57              GL
# 2               Agulha 13 x 45         116              cx
# 3              Agulha 20 x 5,5         127              cx
# 4               Agulha 25 x 07         138              cx
# 5              Agulha 25 x 8,0          94              cx
# 6                Agulha 30 x 7         151              cx
# 7                Agulha 30 x 8         111              cx
# 8               Agulha 40 x 12          24              cx
# 9                    Álcool 70          80          litros
# 10             Álcool Absoluto         357          litros
# 11                  Álcool Gel         224          500 ml
# 12          Algodão Ortopédico           4             pct
# 13  Almofada pra Carimbo Preta           2        unidades
# ...

# %%
import pandas as pd

# Dados existentes no DataFrame
dados = {
    'produto': ['Abaixador de Língua', 'Água Destilada', 'Agulha 13 x 45', 'Agulha 20 x 5,5', 'Agulha 25 x 07', 'Agulha 25 x 8,0', 'Agulha 30 x 7', 'Agulha 30 x 8', 'Agulha 40 x 12', 'Álcool 70', 'Álcool Absoluto', 'Álcool Gel', 'Algodão Ortopédico', 'Almofada pra Carimbo Preta', 'Glicosímetro', 'Atadura de 10 cm', 'Atadura de 15 cm', 'Atadura de 20 cm', 'Atestado Médico', 'Autoclave', 'Avental Manga Longa', 'Avental Manga Curta', 'Bacia Plástica', 'Bexiga', 'Balde de 20 alça metal', 'Balde de 10'],
    'quantidade': [16, 57, 116, 127, 138, 94, 151, 111, 24, 80, 357, 224, 4, 2, 153, 2, 106, 18, 154, 1, 137, 11, 11, 5, 18, 2],
    'grandeza': ['pacote com 100', 'GL', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'cx', 'litros', 'litros', '500 ml', 'pct', 'unidades', 'uni', 'pacotes', 'pacotes', 'pacotes', 'blocos', 'unidade', 'pacotes', 'pacotes', 'unidade', 'pacotes', 'unidades', 'unidades']
}

# Criar DataFrame
df = pd.DataFrame(dados)

# Adicionar nova entrada
nova_entrada = {'produto': 'Bolsa de colostomia', 'quantidade': 40, 'grandeza': 'unidades'}
df = df.append(nova_entrada, ignore_index=True)

# Exportar para Excel
nome_arquivo = 'tabela_produtos.xlsx'
df.to_excel(nome_arquivo, index=False)
print(f"Tabela exportada para '{nome_arquivo}'")
print(df)
df
# Out:
# Tabela exportada para 'tabela_produtos.xlsx'
#                        produto  quantidade        grandeza
# 0          Abaixador de Língua          16  pacote com 100
# 1               Água Destilada          57              GL
# 2               Agulha 13 x 45         116              cx
# 3              Agulha 20 x 5,5         127              cx
# 4               Agulha 25 x 07         138              cx
# 5              Agulha 25 x 8,0          94              cx
# 6                Agulha 30 x 7         151              cx
# 7                Agulha 30 x 8         111              cx
# 8               Agulha 40 x 12          24              cx
# 9                    Álcool 70          80          litros
# 10             Álcool Absoluto         357          litros
# 11                  Álcool Gel         224          500 ml
# 12          Algodão Ortopédico           4             pct
# 13  Almofada pra Carimbo Preta           2        unidades
# ...
